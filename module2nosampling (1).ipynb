# %%
import pandas as pd
from pandas import np
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
m = pd.read_csv("/content/gdrive/My Drive/finalmerge.csv",index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
m
# Out:
#          Unnamed: 0_x  FlightDate  Quarter  ...  WindChillF_y  humidity_y  time_y
# 0                  57  2016-01-01        1  ...            29          66     700
# 1              219870  2016-01-01        1  ...            29          66     700
# 2              356730  2016-01-01        1  ...            29          66     700
# 3              334974  2016-01-01        1  ...            29          66     700
# 4              356750  2016-01-01        1  ...            29          66     700
# ...               ...         ...      ...  ...           ...         ...     ...
# 1815400        453453  2017-09-18        3  ...            69          92    2200
# 1815401        455805  2017-09-21        3  ...            72          75    2200
# 1815402        456636  2017-09-22        3  ...            71          63    2200
# 1815403        457242  2017-09-23        3  ...            86          55    2100
# 1815404        458172  2017-09-24        3  ...            74          87    2200
#
# [1815405 rows x 50 columns]

# %%
m.describe()
# Out:
#        Unnamed: 0_x       Quarter  ...    humidity_y        time_y
# count  1.815405e+06  1.815405e+06  ...  1.815405e+06  1.815405e+06
# mean   2.201694e+05  2.515150e+00  ...  6.345448e+01  1.297760e+03
# std    1.449516e+05  1.104474e+00  ...  2.245897e+01  5.026491e+02
# min    0.000000e+00  1.000000e+00  ...  3.000000e+00  0.000000e+00
# 25%    9.091400e+04  2.000000e+00  ...  4.800000e+01  9.000000e+02
# 50%    2.067500e+05  3.000000e+00  ...  6.700000e+01  1.300000e+03
# 75%    3.458240e+05  3.000000e+00  ...  8.200000e+01  1.700000e+03
# max    5.104440e+05  4.000000e+00  ...  1.000000e+02  2.300000e+03
#
# [8 rows x 43 columns]

# %%
m['ArrDelayMinutes'].mean()
# Out:
# 14.231424943745335

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.stripplot(y="ArrDelayMinutes", data=m,color = 'red')

# %%
d=m.drop(["DepTime","DepDel15","DepDelayMinutes","ArrDelayMinutes","ArrTime","ArrDel15","Unnamed: 0_x","Unnamed: 0_y","Unnamed: 0.1","Origin","Dest","airport_x","airport_y","FlightDate","date_y","date_x","time_x","time_y"],axis=1)
d
# Out:
#          Quarter  Year  Month  ...  tempF_y  WindChillF_y  humidity_y
# 0              1  2016      1  ...       34            29          66
# 1              1  2016      1  ...       34            29          66
# 2              1  2016      1  ...       34            29          66
# 3              1  2016      1  ...       34            29          66
# 4              1  2016      1  ...       34            29          66
# ...          ...   ...    ...  ...      ...           ...         ...
# 1815400        3  2017      9  ...       69            69          92
# 1815401        3  2017      9  ...       72            72          75
# 1815402        3  2017      9  ...       71            71          63
# 1815403        3  2017      9  ...       86            86          55
# 1815404        3  2017      9  ...       74            74          87
#
# [1815405 rows x 32 columns]

# %%
d.shape
# Out:
# (1815405, 32)

# %%
e=m["ArrDel15"]

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(d, e, test_size = 0.20, random_state = None)

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc=ExtraTreesClassifier(n_jobs=-1,random_state = None)
etc.fit(X_train,Y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
Y_predetc=etc.predict(X_test)

# %%
#ACCURACY
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_predetc)
# Out:
# 0.793029654539896

# %%
from sklearn import metrics
cm=metrics.confusion_matrix(Y_test,Y_predetc)
print(cm)
# Out:
# [[264902  22044]
#  [ 53103  23032]]

# %%
from sklearn.metrics import classification_report
target_names=["Class 0","Class 1"]
print(classification_report(Y_test,Y_predetc,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.92      0.88    286946
#      Class 1       0.51      0.30      0.38     76135
#
#     accuracy                           0.79    363081
#    macro avg       0.67      0.61      0.63    363081
# weighted avg       0.77      0.79      0.77    363081

# %%
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier

clf=DecisionTreeClassifier()
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#XGBoost
import xgboost 
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
X_test_np = X_test.values

# %%
Y_predxgb=model.predict(X_test)

# %%
#from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_predxgb)
# Out:
# 0.7957122515361585

# %%
#from sklearn import metrics
cm=metrics.confusion_matrix(Y_test,Y_predxgb)
print(cm)
# Out:
# [[285289   1657]
#  [ 72516   3619]]

# %%
target_names=["Class 0","Class 1"]
print(classification_report(Y_test,Y_predxgb,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.99      0.88    286946
#      Class 1       0.69      0.05      0.09     76135
#
#     accuracy                           0.80    363081
#    macro avg       0.74      0.52      0.49    363081
# weighted avg       0.77      0.80      0.72    363081

# %%
#logistic regression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(d,e,test_size=0.25,random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
pd.DataFrame(cnf_matrix)
target_names=["Class 0","Class 1"]

# %%
print(classification_report(y_test, y_pred,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      1.00      0.88    358997
#      Class 1       0.54      0.01      0.02     94855
#
#     accuracy                           0.79    453852
#    macro avg       0.67      0.50      0.45    453852
# weighted avg       0.74      0.79      0.70    453852
